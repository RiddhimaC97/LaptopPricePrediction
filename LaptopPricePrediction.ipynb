# %%
import time
StartTime=time.time()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the dataset
LaptopPriceData=pd.read_csv(filepath_or_buffer="C:/Users/RIDDHIMA/Desktop/LaptopPricePrediction.csv",
                          sep=',', encoding='latin-1', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
LaptopPriceData.head(40)
######
LaptopPriceData.replace('8 GB','8',inplace=True)

LaptopPriceData.replace('4 GB','4',inplace=True)
LaptopPriceData.replace('16 G','16',inplace=True)
LaptopPriceData.replace('12 G','12',inplace=True)
LaptopPriceData.replace('32 G','32',inplace=True)

LaptopPriceData.head(20)
####storage data manipulation
LaptopPriceData.replace('1 TB HDD','1',inplace=True)
LaptopPriceData.replace('1 TB SSD','1.1',inplace=True)
LaptopPriceData.replace('256 GB SSD','256',inplace=True)
LaptopPriceData.replace('128 GB SSD','128',inplace=True)
LaptopPriceData.replace('1 TB HDD|256 GB SSD','1.256',inplace=True)
LaptopPriceData.replace('512 GB SSD','512',inplace=True)
LaptopPriceData.replace('512 GB HDD|512 GB SSD','512.512',inplace=True)
#####
LaptopPriceData.replace('M.2 Slot for SSD Upgrade','0',inplace=True)
LaptopPriceData.replace('1 TB HDD|128 GB SSD','1.128',inplace=True)
LaptopPriceData.replace('1 TB HDD|512 GB SSD','1.512',inplace=True)
LaptopPriceData.head(30)
#######
LaptopPriceData.replace('64 bit Windows 10 Operating System','1',inplace=True)

LaptopPriceData.replace('64 bit Chrome Operating System','1',inplace=True)
LaptopPriceData.replace('Mac OS Operating System','2',inplace=True)
LaptopPriceData.replace('Windows 10 Operating System','1.1',inplace=True)

LaptopPriceData.head(40)
LaptopPriceData.replace('Intel Core i5 Processor (10th Gen)','5',inplace=True)
LaptopPriceData.replace('Intel Core i3 Processor (11th Gen)','3',inplace=True)
LaptopPriceData.replace('Intel Core i7 Processor (10th Gen)','7',inplace=True)
LaptopPriceData.replace('AMD Ryzen 5 Quad Core Processor','5.1',inplace=True)
LaptopPriceData.replace('AMD Ryzen 3 Dual Core Processor','3.1',inplace=True)
LaptopPriceData.replace('AMD Ryzen 7 Octa Core Processor','7.1',inplace=True)
LaptopPriceData.head(40)
##########
LaptopPriceData.replace('14 In','14',inplace=True)
LaptopPriceData.replace('14 in','14',inplace=True)
LaptopPriceData.replace('13 in','13',inplace=True)
LaptopPriceData.replace('13 In','13',inplace=True)
LaptopPriceData.replace('12 In','12',inplace=True)
LaptopPriceData.replace('12 in','12',inplace=True)
LaptopPriceData.replace('16 in','16',inplace=True)
LaptopPriceData.replace('16 In','16',inplace=True)
#######
LaptopPriceData=LaptopPriceData[LaptopPriceData["RAM"].str.contains("s Ful") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Operating System"].str.contains("s Ful") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Storage"].str.contains("s Ful") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Display"].str.contains("s Ful") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Price"].str.contains("s Ful") == False]
########
LaptopPriceData=LaptopPriceData[LaptopPriceData["RAM"].str.contains("play,") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Operating System"].str.contains("play,") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Storage"].str.contains("play,") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Display"].str.contains("play,") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Price"].str.contains("play,") == False]
######
LaptopPriceData=LaptopPriceData[LaptopPriceData["RAM"].str.contains("Upgr") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Operating System"].str.contains("Upgr") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Storage"].str.contains("Upgr") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Display"].str.contains("Upgr") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Price"].str.contains("Upgr") == False]
###########
LaptopPriceData=LaptopPriceData[LaptopPriceData["RAM"].str.contains("DOS Operating System") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Operating System"].str.contains("DOS Operating System") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Storage"].str.contains("DOS Operating System") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Display"].str.contains("DOS Operating System") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Price"].str.contains("DOS Operating System") == False]
######
LaptopPriceData=LaptopPriceData[LaptopPriceData["RAM"].str.contains("elSer") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Operating System"].str.contains("elSer") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Storage"].str.contains("elSer") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Display"].str.contains("elSer") == False]
LaptopPriceData=LaptopPriceData[LaptopPriceData["Price"].str.contains("elSer") == False]
#########


LaptopPriceData.head()
# Out:
#   Name                          Processor RAM Operating System Storage  \
# 0  Len                                  5   8                1       1
# 1  Len                                  3   8                1     256
# 2  HP   Intel Pentium Quad Core Processor   8                1     256
# 3  HP                                   3   8                1     256
# 4  HP      AMD Athlon Dual Core Processor   4                1       1
#
#   Display  Price
# 0    15.6  43990
# 1      14  43990
# 2      14  31490
# 3      14  40990
# 4    15.6  27490

# %%
LaptopPriceData['RAM']=LaptopPriceData['RAM'].astype(float)
LaptopPriceData['Operating System']=LaptopPriceData['Operating System'].astype(float)
LaptopPriceData['Display']=LaptopPriceData['Display'].astype(float)
LaptopPriceData['Storage']=LaptopPriceData['Storage'].astype(float)
LaptopPriceData['Price']=LaptopPriceData['Price'].astype(float)

# %%
LaptopPriceData.describe(include="all")
#mean price of latops listed=₹79,966
#minimum price of laptops listed=₹17,990
#maximum price of laptops listed=₹3,38,990
# Out:
#        Name Processor         RAM  Operating System     Storage     Display  \
# count   487       487  487.000000        487.000000  487.000000  487.000000
# unique   14        39         NaN               NaN         NaN         NaN
# top     Len         7         NaN               NaN         NaN         NaN
# freq    127        87         NaN               NaN         NaN         NaN
# mean    NaN       NaN    9.905544          1.045175  238.650193   14.708008
# std     NaN       NaN    4.645378          0.198793  236.073520    0.972628
# min     NaN       NaN    4.000000          1.000000    0.000000   11.600000
# 25%     NaN       NaN    8.000000          1.000000    1.100000   14.000000
# 50%     NaN       NaN    8.000000          1.000000  256.000000   15.600000
# 75%     NaN       NaN   16.000000          1.000000  512.000000   15.600000
# max     NaN       NaN   32.000000          2.000000  512.512000   17.300000
#
#                 Price
# count      487.000000
# ...

# %%
LaptopPriceData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 487 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              487 non-null    object
#  1   Processor         487 non-null    object
#  2   RAM               487 non-null    float64
#  3   Operating System  487 non-null    float64
#  4   Storage           487 non-null    float64
#  5   Display           487 non-null    float64
#  6   Price             487 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 30.4+ KB

# %%
#visualizing the price range of laptops

# %matplotlib inline
Plot=['Price']
LaptopPriceData[Plot].hist(color='blue')
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
sns.barplot(x=LaptopPriceData['RAM'],y=LaptopPriceData['Price'])
plt.show()

# %%
sns.scatterplot(x=LaptopPriceData['Storage'],y=LaptopPriceData['Price'])
# Out:
# <AxesSubplot:xlabel='Storage', ylabel='Price'>

# %%
Filter1=LaptopPriceData['Price']>=200000

# %%
LaptopPriceData[Filter1]
#number of laptops priced above Rs.2,00,000
len(LaptopPriceData[Filter1])
# Out:
# 14

# %%
#checking for null values
LaptopPriceData.isnull().sum()
# Out:
# Unnamed: 0            0
# Name                  0
# Processor           550
# RAM                   0
# Operating System      0
# Storage               0
# Display               0
# Warranty              0
# rating                0
# Price                 0
# dtype: int64

# %%
SelectedColumns=['RAM','Operating System','Storage','Display','Price']
DataForML=LaptopPriceData[SelectedColumns]
DataForML.head(5)
# Out:
#    RAM  Operating System  Storage  Display    Price
# 0  8.0               1.0      1.0     15.6  43990.0
# 1  8.0               1.0    256.0     14.0  43990.0
# 2  8.0               1.0    256.0     14.0  31490.0
# 3  8.0               1.0    256.0     14.0  40990.0
# 4  4.0               1.0      1.0     15.6  27490.0

# %%
DataML=DataForML.rename(columns = {"New_Price":"Price"})

# %%
DataML.head()
# Out:
#    RAM  Operating System  Storage  Display    Price
# 0  8.0               1.0      1.0     15.6  43990.0
# 1  8.0               1.0    256.0     14.0  43990.0
# 2  8.0               1.0    256.0     14.0  31490.0
# 3  8.0               1.0    256.0     14.0  40990.0
# 4  4.0               1.0      1.0     15.6  27490.0

# %%
# Calculating correlation matrix
ContinuousCols=['Price','RAM','Operating System','Storage','Display']

# Creating the correlation matrix
CorrelationData=LaptopPriceData[ContinuousCols].corr()
CorrelationData
# Out:
#                      Price       RAM  Operating System   Storage   Display
# Price             1.000000  0.560304          0.249213 -0.047724 -0.047756
# RAM               0.560304  1.000000          0.024238  0.002236 -0.037813
# Operating System  0.249213  0.024238          1.000000 -0.051088 -0.073707
# Storage          -0.047724  0.002236         -0.051088  1.000000 -0.013319
# Display          -0.047756 -0.037813         -0.073707 -0.013319  1.000000

# %%
TargetVariable='Price'
Predictors=['RAM', 'Operating System', 'Storage', 'Display']



X=DataML[Predictors].values
y=DataML[TargetVariable].values

# Split the data into training and testing set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
# Multiple Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

# Printing all the parameters of Linear regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)

# Taking the standardized values to original scale


from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
prediction=LREG.predict(X_test)
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)


# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Price']-TestingDataResults['PredictedPrice']))/TestingDataResults['Price'])

# Printing sample prediction values
print(TestingDataResults[[TargetVariable,'Predicted'+TargetVariable, 'APE']].head())


MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression()
# R2 Value: 0.3907701448743467
#
# ##### Model Validation and Accuracy Calculations ##########
#      Price  PredictedPrice        APE
# 0  50000.0         69382.0  38.764000
# 1  43990.0         69383.0  57.724483
# 2  62990.0         69384.0  10.150818
# 3  67990.0         69701.0   2.516547
# 4  50990.0         67981.0  33.322220
# Mean Accuracy on test data: 65.7223958846351
# Median Accuracy on test data: 77.21306209850107
#
# Accuracy values for 10-fold Cross Validation:
#  [54.79623601 75.39098579 73.98360988 80.01780577 76.00405774 73.88796411
#  78.98445774 57.22444475 38.80032137 31.11194666]
#
# Final Average Accuracy of the model: 64.02
